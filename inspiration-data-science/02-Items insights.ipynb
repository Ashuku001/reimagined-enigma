# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.style

# from mlxtend.frequent_patterns import apriori,association_rules
from collections import Counter
from IPython.display import Image

# %%
import warnings
warnings.filterwarnings("ignore", category=pd.errors.DtypeWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.simplefilter("ignore", category=NameError)
warnings.simplefilter("ignore", category=DeprecationWarning)

# %%
products = pd.read_excel("Data/Rec_sys_data.xlsx", sheet_name="product")
products = products.dropna()

# %%
products.shape
# Out:
# (3706, 6)

# %%
products.head()
# Out:
#   StockCode                                       Product Name  \
# 0     22629  Ganma Superheroes Ordinary Life Case For Samsu...
# 1     21238  Eye Buy Express Prescription Glasses Mens Wome...
# 2     22181  MightySkins Skin Decal Wrap Compatible with Ni...
# 3     84879  Mediven Sheer and Soft 15-20 mmHg Thigh w/ Lac...
# 4     84836      Stupell Industries Chevron Initial Wall D cor
#
#                                          Description  \
# 0  New unique design, great gift.High quality pla...
# 1  Rounded rectangular cat-eye reading glasses. T...
# 2  Each Nintendo 2DS kit is printed with super-hi...
# 3  The sheerest compression stocking in its class...
# 4  Features: -Made in the USA. -Sawtooth hanger o...
#
#                                             Category               Brand  \
# 0  Cell Phones|Cellphone Accessories|Cases & Prot...               Ganma
# 1          Health|Home Health Care|Daily Living Aids     Eye Buy Express
# 2  Video Games|Video Game Accessories|Accessories...         Mightyskins
# 3          Health|Medicine Cabinet|Braces & Supports                Medi
# 4  Home Improvement|Paint|Wall Decals|All Wall De...  Stupell Industries
#
#    Unit Price
# 0       13.99
# 1       19.22
# 2       14.99
# 3       62.38
# 4       35.99

# %%
products_2 = products.drop_duplicates(subset=["Product Name", "Description"], keep="first")

# %%
products_2.shape
# Out:
# (723, 6)

# %%
list(products_2["StockCode"])
# Out:
# [22629,
#  21238,
#  22181,
#  84879,
#  84836,
#  22716,
#  23357,
#  'M',
#  23283,
#  22098,
#  21621,
#  23355,
#  21155,
#  23110,
#  22952,
#  21246,
#  20972,
#  22037,
#  85178,
#  '85180B',
#  22139,
#  22402,
#  23343,
#  23661,
#  21498,
#  84991,
#  84978,
#  21264,
#  20728,
#  22970,
#  82486,
#  21932,
#  22734,
#  84378,
#  23345,
#  23084,
#  21259,
#  21864,
#  82600,
#  23193,
#  21217,
#  84012,
#  22652,
#  23424,
#  21232,
#  23236,
#  22776,
#  23217,
#  '85099F',
#  23245,
#  22625,
#  22866,
#  21086,
#  23321,
#  22906,
#  22326,
#  21992,
#  21928,
#  21802,
#  '79063D',
#  22470,
#  22677,
#  22857,
#  23206,
#  22609,
#  23007,
#  22277,
#  22085,
#  22437,
#  22620,
#  23120,
#  21871,
#  21791,
#  21915,
#  21936,
#  21524,
#  '16258A',
#  22173,
#  48194,
#  22502,
#  22086,
#  21128,
#  20677,
#  23012,
#  23297,
#  23083,
#  23581,
#  22042,
#  22745,
#  21068,
#  22815,
#  23230,
#  23204,
#  22847,
#  23294,
#  23551,
#  22607,
#  21844,
#  23080,
#  '85199S',
#  23173,
#  '47503A',
#  '84596B',
#  22568,
#  '17012F',
#  22212,
#  22619,
#  22935,
#  21071,
#  22891,
#  22621,
#  22818,
#  '84509A',
#  16238,
#  '90161A',
#  23392,
#  21154,
#  22623,
#  23328,
#  21452,
#  22722,
#  '47590A',
#  22055,
#  22082,
#  22837,
#  23166,
#  21981,
#  23147,
#  23350,
#  23167,
#  '15056N',
#  22422,
#  23322,
#  23065,
#  23089,
#  22856,
#  21539,
#  22170,
#  '84997c',
#  35970,
#  '85039A',
#  22382,
#  '84509E',
#  22616,
#  16045,
#  20867,
#  23396,
#  21272,
#  21989,
#  21696,
#  22817,
#  22070,
#  21906,
#  22562,
#  22602,
#  22156,
#  '84531B',
#  22035,
#  23289,
#  22245,
#  22960,
#  22558,
#  20971,
#  22439,
#  22739,
#  21181,
#  22178,
#  21754,
#  21035,
#  22472,
#  22555,
#  23229,
#  21931,
#  21479,
#  21014,
#  22150,
#  22993,
#  22129,
#  22111,
#  22649,
#  20982,
#  22680,
#  '84509B',
#  23402,
#  22589,
#  23388,
#  84686,
#  23569,
#  22794,
#  82482,
#  85066,
#  22710,
#  23187,
#  21175,
#  22065,
#  90098,
#  22678,
#  22321,
#  22751,
#  22944,
#  22992,
#  22659,
#  22956,
#  21742,
#  21917,
#  85078,
#  22580,
#  84944,
#  23275,
#  '47574A',
#  23323,
#  22727,
#  22699,
#  22411,
#  22729,
#  22149,
#  84945,
#  22356,
#  20724,
#  '85017B',
#  '51014C',
#  21615,
#  22597,
#  22943,
#  21868,
#  23016,
#  22262,
#  84992,
#  21744,
#  22858,
#  22644,
#  84380,
#  16016,
#  22914,
#  22995,
#  22781,
#  21506,
#  22821,
#  22783,
#  82567,
#  23032,
#  '85071C',
#  21808,
#  21793,
#  21884,
#  85038,
#  '85049C',
#  21733,
#  23499,
#  21390,
#  22365,
#  '85114A',
#  22214,
#  22242,
#  22919,
#  23183,
#  22673,
#  23538,
#  20998,
#  22077,
#  21136,
#  '84247G',
#  '72801d',
#  21622,
#  84840,
#  20981,
#  22979,
#  16218,
#  '84913A',
#  23175,
#  22715,
#  22696,
#  23452,
#  22487,
#  '90198A',
#  21955,
#  84832,
#  22168,
#  22927,
#  22560,
#  '84508B',
#  23437,
#  21579,
#  22749,
#  '85049H',
#  22320,
#  23177,
#  21934,
#  22324,
#  23556,
#  21642,
#  23497,
#  82552,
#  21033,
#  20964,
#  '90209C',
#  22473,
#  22915,
#  22627,
#  22249,
#  22550,
#  22153,
#  20674,
#  22244,
#  84347,
#  71053,
#  22865,
#  23222,
#  20974,
#  21916,
#  22430,
#  23266,
#  22949,
#  '90197B',
#  '47503H',
#  23213,
#  22332,
#  23178,
#  21774,
#  84792,
#  21313,
#  21135,
#  23199,
#  21812,
#  21985,
#  85152,
#  '84660C',
#  23664,
#  22026,
#  23394,
#  '90013C',
#  22900,
#  21794,
#  23352,
#  20734,
#  20996,
#  23171,
#  '37488A',
#  22874,
#  21811,
#  21509,
#  21918,
#  85204,
#  22798,
#  22565,
#  21069,
#  21448,
#  22232,
#  22305,
#  21654,
#  23411,
#  23191,
#  21935,
#  21623,
#  23414,
#  '85230A',
#  22517,
#  72819,
#  22654,
#  22599,
#  22027,
#  20658,
#  22748,
#  21288,
#  23180,
#  22488,
#  84950,
#  22436,
#  22294,
#  46118,
#  '15056BL',
#  23306,
#  21688,
#  23568,
#  '84519B',
#  22829,
#  23366,
#  23239,
#  23068,
#  23314,
#  90100,
#  '84993A',
#  84466,
#  23205,
#  21159,
#  23186,
#  22302,
#  23485,
#  21402,
#  22270,
#  22046,
#  21041,
#  23094,
#  22031,
#  23315,
#  23049,
#  23154,
#  22376,
#  '85232D',
#  22838,
#  '84859A',
#  22813,
#  22982,
#  21039,
#  21619,
#  22304,
#  21454,
#  22917,
#  22738,
#  21385,
#  22524,
#  23225,
#  22969,
#  23460,
#  23368,
#  23008,
#  22260,
#  '85025C',
#  20615,
#  '85024C',
#  '84849D',
#  22972,
#  22083,
#  22849,
#  '47591B',
#  21677,
#  23412,
#  85016,
#  22503,
#  21215,
#  20985,
#  '85135B',
#  23157,
#  22314,
#  'S',
#  85116,
#  '35001G',
#  21520,
#  '37479P',
#  20897,
#  21042,
#  23542,
#  23310,
#  22182,
#  22754,
#  22842,
#  '84927D',
#  '84707B',
#  21126,
#  20669,
#  85106,
#  '85034C',
#  22393,
#  23347,
#  22637,
#  20796,
#  '17090D',
#  22354,
#  21164,
#  23358,
#  '72351A',
#  '35810A',
#  21195,
#  22684,
#  '47567B',
#  21823,
#  22427,
#  '90130B',
#  '85180A',
#  '90184B',
#  23092,
#  16225,
#  23242,
#  23039,
#  21591,
#  21263,
#  '47594B',
#  23416,
#  23553,
#  23415,
#  23406,
#  22593,
#  '84910A',
#  82551,
#  23444,
#  23555,
#  '90200E',
#  '72807A',
#  21040,
#  20931,
#  90094,
#  '84086C',
#  84499,
#  23303,
#  '85231G',
#  22741,
#  22862,
#  '90201D',
#  37501,
#  21872,
#  23381,
#  '85031A',
#  '17012C',
#  20857,
#  '37491D',
#  84598,
#  21781,
#  35967,
#  '84673A',
#  23267,
#  23451,
#  22826,
#  21311,
#  '35911B',
#  '37489A',
#  21359,
#  22345,
#  22021,
#  22519,
#  22890,
#  '84857C',
#  20684,
#  23270,
#  23421,
#  '35598B',
#  22406,
#  '72802B',
#  '84707A',
#  22040,
#  '84898F',
#  21458,
#  '85170D',
#  23523,
#  21336,
#  22575,
#  23401,
#  21739,
#  23464,
#  21946,
#  '85023B',
#  '37482P',
#  '17084R',
#  21709,
#  21100,
#  '84924A',
#  '84927A',
#  16052,
#  22709,
#  21394,
#  23150,
#  20699,
#  '46775D',
#  22903,
#  '46000U',
#  21285,
#  21250,
#  22832,
#  75178,
#  21683,
#  21467,
#  79329,
#  22313,
#  21310,
#  21260,
#  '84509c',
#  23398,
#  22307,
#  22719,
#  '85179A',
#  22687,
#  '72802A',
#  21063,
#  84227,
#  23047,
#  23524,
#  '84535A',
#  '84989a',
#  23644,
#  22954,
#  '85025B',
#  20803,
#  '84804B',
#  22855,
#  23359,
#  23475,
#  23660,
#  21368,
#  22119,
#  20756,
#  21196,
#  22394,
#  23507,
#  84915,
#  '90003C',
#  44235,
#  '84800L',
#  84576,
#  35653,
#  'gift_0001_10',
#  84816,
#  22034,
#  '90195A',
#  84631,
#  23046,
#  23477,
#  44234,
#  23468,
#  '90016B',
#  72815,
#  84843,
#  20769,
#  20748,
#  '90175C',
#  21743,
#  21031,
#  '90125D',
#  37343,
#  79331,
#  '85230E',
#  21690,
#  22145,
#  23611,
#  21349,
#  '85205B',
#  21750,
#  23562,
#  85198,
#  '90198B',
#  90144,
#  '90000A',
#  '90059F',
#  '84531A',
#  '47341B',
#  20827,
#  '85188B',
#  85125,
#  '84661C',
#  '90030A',
#  23019,
#  '79071B',
#  85215,
#  21269,
#  90091,
#  22157,
#  22770,
#  23607,
#  '90026D',
#  20759,
#  '16202E',
#  35832,
#  '90141A',
#  21720,
#  84192,
#  84723,
#  '90160C',
#  20802,
#  21821,
#  '90179C',
#  '90058A',
#  23430,
#  21722,
#  16010,
#  '90175D',
#  '84415B',
#  90204,
#  '84993B',
#  '90040A',
#  21657,
#  90101,
#  '84562A',
#  '84952A',
#  '79062D',
#  23645,
#  84975,
#  '35271S',
#  '85018B',
#  23463,
#  '35001W',
#  37423,
#  20845,
#  90076,
#  '90209A',
#  35645,
#  '84967A',
#  '90176D',
#  37509,
#  '84984B',
#  22828,
#  '37444B',
#  22987,
#  '90025A',
#  84497,
#  '79157B',
#  23448,
#  '90126A',
#  '90025F',
#  '90024D',
#  84691,
#  '90128A',
#  23621,
#  '84845D',
#  '72803B',
#  '90027D',
#  23627,
#  '90013D',
#  '90142A',
#  21653,
#  '84966B',
#  21160,
#  '90011C',
#  '47503J',
#  '84802B',
#  '85023C',
#  'DCGS0072',
#  '35833G',
#  23605,
#  21134,
#  90021,
#  84620,
#  '90187A',
#  '90037D',
#  '84612B',
#  '16161M']

# %%
categories = [{"name": p.split("|")[0], "storeId": 1, "billboardId": 1} for p in products_2.Category.values]

# %%
def increment_counter():
    if not hasattr(increment_counter, "counter"):
        increment_counter.counter = 55  # Initialize it for the first time
    increment_counter.counter += 1
    return increment_counter.counter
increment_counter()
# Out:
# 56

# %%
unique_cat = set(item["name"] for item in categories)
categories = [{"id": increment_counter(), "name": c, "storeId": 1, "billboardId": 1, "createdAt": "DATE", "updatedAt": "DATE"} for c in unique_cat]
len(categories), len(unique_cat)
# Out:
# (29, 29)

# %%
categories[0]
# Out:
# {'id': 57,
#  'name': 'Arts, Crafts & Sewing',
#  'storeId': 1,
#  'billboardId': 1,
#  'createdAt': 'DATE',
#  'updatedAt': 'DATE'}

# %%
with open('categories.txt', 'w') as file:
    for dictionary in categories:
        # Write the dictionary as a string
        file.write(str(dictionary) + ',\n')

# %%
brands = [{"name": p, "storeId": 1, "industry": p} for p in products_2.Brand.values]

# %%
unique_brands = set(item["name"] for item in brands)
brands = [{"id": increment_counter(), "name": c, "storeId": 1, "email": "ashukuezra@gmail.com", "phoneNumber": "254707737397", "joinDate": "DATE", "createdAt": "DATE", "updatedAt": "DATE"} for c in unique_brands]
len(brands), len(unique_brands)
# Out:
# (510, 510)

# %%
brands[0]
# Out:
# {'id': 57,
#  'name': 'Natural Balance',
#  'storeId': 1,
#  'email': 'ashukuezra@gmail.com',
#  'phoneNumber': '254707737397',
#  'joinDate': 'DATE',
#  'createdAt': 'DATE',
#  'updatedAt': 'DATE'}

# %%
with open('brands.txt', 'w') as file:
    for dictionary in brands:
        # Write the dictionary as a string
        file.write(str(dictionary) + ',\n')

# %%
products = products_2.rename(columns={"Product Name": "name",  "Description": "description",
         "StockCode": "stockCode",
        "Unit Price": "price",
        "Brand": "brand",
        "Category": "category"})

# %%
def increment_counter():
    if not hasattr(increment_counter, "counter"):
        increment_counter.counter = 55  # Initialize it for the first time
    increment_counter.counter += 1
    return increment_counter.counter
increment_counter()
# Out:
# 56

# %%
def get_id(id):
    try:
        return int(id)
    except:
        return increment_counter()

# %%
new_products = [{
        "name": row["name"],
        "description": row["description"],
        "stockCode": row["stockCode"],
        "price": row["price"],
        "brand": row["brand"],
        "category": row["category"].split("|")[0]
    } for index, row in products.iterrows()]

# %%
def find_item(list_of_dicts, key, value):
    for item in list_of_dicts:
        if item.get(key) == value:
            return item["id"]
    return None

# %%
new_products[0]
# Out:
# {'name': 'Ganma Superheroes Ordinary Life Case For Samsung Galaxy Note 5 Hard Case Cover',
#  'description': 'New unique design, great gift.High quality plastic material.Clips over the back of the device to protect the back &amp; sides from bumps and scratches.Printed using a process called sublimation, high quality image which will last for years!| New unique design, great gift. High quality plastic material. Clips over the back of the device to protect the back &amp; sides from bumps and scratches. Printed using a process called sublimation, high quality image which will last for years! ',
#  'stockCode': 22629,
#  'price': 13.99,
#  'brand': 'Ganma',
#  'category': 'Cell Phones'}

# %%
temp = [{"name": row["name"],
        "description": row["description"],
        "stockCode": str(row["stockCode"]),
        "id": get_id(row["stockCode"]),
        "price": row["price"],
        "brandId": find_item(brands, "name", row["brand"]),
        "isFeatured": True,
        "isArchived": True,
        "storeId": 1,
        "createdAt": "DATE-TIME",
        "updatedAt": "DATE-TIME",
        "categoryId": find_item(categories, "name", row["category"])
        } for row in new_products]

# %%
len(new_products)
# Out:
# 723

# %%
with open('products.txt', 'w') as file:
    for dictionary in temp:
        # Write the dictionary as a string
        file.write(str(dictionary) + ',\n')

# %%
import ast

def read_and_parse_file(file_path):
    with open(file_path, 'r') as file:
        content = file.read().strip()

    # Remove the trailing comma and newline if present
    if content.endswith(','):
        content = content[:-1]

    # Split the content by '},\n' to separate each dictionary
    raw_items = content.split('},\n')

    items = []
    for raw_item in raw_items:
        # Add back the removed '}' (except for the last item)
        if not raw_item.endswith('}'):
            raw_item = raw_item + '}'
        # Use ast.literal_eval to safely evaluate the string to a dictionary
        item = ast.literal_eval(raw_item.strip())
        items.append(item)
    
    return items

# %%
items = read_and_parse_file("products.txt")

# %%
ids = [item["id"] for item in items]

# %%
with open ("productIds", "w") as file:
    for id in ids:
        file.write(str(id) + ",")
